# %%
# Import libraries and load dataset
import os
import sys
import importlib
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm

import common.common as common
importlib.reload(common)

df = pd.read_csv("Data.csv")

yr = list(df.yr)
df = df.set_index("yr")
df["yr"] = yr
df
# Out:
#       inbtou_volume  inbtou_spending  covid19_cases  covid19_deaths
# yr
# 2010       231120.0       86099000.0              0               0  \
# 2011       208000.0       91593500.0              0               0
# 2012       199840.0       94054000.0              0               0
# 2013       200120.0       92252100.0              0               0
# 2014       204930.0       92292800.0              0               0
# 2015       206660.0       95648700.0              0               0
# 2016       223160.0      100025800.0              0               0
# 2017       303040.0       95008600.0              0               0
# 2018       356070.0      104280800.0              0               0
# 2019       404100.0      117778400.0              0               0
# 2020       154830.0       43715500.0            121               0
# 2021        56760.0       36274800.0           5729              81
# 2022            NaN              NaN           3688              38
#
#       covid19_mortality    yr
# yr
# 2010           0.000000  2010
# 2011           0.000000  2011
# 2012           0.000000  2012
# 2013           0.000000  2013
# 2014           0.000000  2014
# 2015           0.000000  2015
# 2016           0.000000  2016
# 2017           0.000000  2017
# 2018           0.000000  2018
# 2019           0.000000  2019
# 2020           0.000000  2020
# 2021           0.014139  2021
# 2022           0.010304  2022

# %%
# Set up plot
plt.title('St Vincent and the Grenadines')
plt.ylabel('Number of tourists')
plt.xlim(2009, 2022)
y_name = 'inbtou_volume'

# Filter out NaN data
_df = pd.DataFrame(df).loc[df[y_name].notna()]

# Generate difference-in-differences plot
effect, stderr = common.gen_did_plot(_df, y_name)
print(f"Estimated COVID-19 effect: {int(effect)} ± {int(stderr)} (95% confidence)")

# Render plot
plt.show()

# Run OLS regression
common.run_covid19_regression(_df, y_name, log_level=True)
# Out:
# Estimated COVID-19 effect: -259309 ± 54251 (95% confidence)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_inbtou_volume   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     27.33
# Date:                Wed, 26 Apr 2023   Prob (F-statistic):           0.000148
# Time:                        15:49:08   Log-Likelihood:                 6.5235
# No. Observations:                  12   AIC:                            -5.047
# Df Residuals:                       8   BIC:                            -3.107
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               -124.4375     38.164     -3.261      0.012    -212.444     -36.431
# yr                         0.0679      0.019      3.586      0.007       0.024       0.112
# covid19_cases             -0.0069      0.002     -4.003      0.004      -0.011      -0.003
# covid19_cases:ind_2021     0.0066      0.002      3.839      0.005       0.003       0.011
# ==============================================================================
# Omnibus:                        0.572   Durbin-Watson:                   0.666
# Prob(Omnibus):                  0.751   Jarque-Bera (JB):                0.554
# Skew:                           0.130   Prob(JB):                        0.758
# Kurtosis:                       1.980   Cond. No.                     1.93e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_inbtou_volume   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     12.36
# Date:                Wed, 26 Apr 2023   Prob (F-statistic):            0.00262
# Time:                        15:49:08   Log-Likelihood:              -0.074396
# No. Observations:                  12   AIC:                             6.149
# Df Residuals:                       9   BIC:                             7.604
# Df Model:                           2
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                 -48.1068     54.014     -0.891      0.396    -170.294      74.081
# yr                          0.0300      0.027      1.120      0.292      -0.031       0.091
# covid19_deaths             -0.0099      0.002     -4.786      0.001      -0.015      -0.005
# covid19_deaths:ind_2021    -0.0099      0.002     -4.786      0.001      -0.015      -0.005
# ==============================================================================
# Omnibus:                        2.281   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.320   Jarque-Bera (JB):                0.488
# Skew:                          -0.414   Prob(JB):                        0.784
# Kurtosis:                       3.540   Cond. No.                     2.01e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_inbtou_volume   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     12.36
# Date:                Wed, 26 Apr 2023   Prob (F-statistic):            0.00262
# Time:                        15:49:08   Log-Likelihood:              -0.074396
# No. Observations:                  12   AIC:                             6.149
# Df Residuals:                       9   BIC:                             7.604
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -48.1068     54.014     -0.891      0.396    -170.294      74.081
# yr                             0.0300      0.027      1.120      0.292      -0.031       0.091
# covid19_mortality            -56.6638     11.840     -4.786      0.001     -83.448     -29.880
# covid19_mortality:ind_2021   -56.6638     11.840     -4.786      0.001     -83.448     -29.880
# ==============================================================================
# Omnibus:                        2.281   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.320   Jarque-Bera (JB):                0.488
# Skew:                          -0.414   Prob(JB):                        0.784
# Kurtosis:                       3.540   Cond. No.                     4.69e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.22e-36. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
# Set up plot
plt.title('St Vincent and the Grenadines')
plt.ylabel('Tourist expenditure (USD)')
plt.xlim(2009, 2022)
y_name = 'inbtou_spending'

# Filter out NaN data
_df = pd.DataFrame(df).loc[df[y_name].notna()]

# Generate difference-in-differences plot
effect, stderr = common.gen_did_plot(_df, y_name)
print(f"Estimated COVID-19 effect: {int(effect)} ± {int(stderr)} (95% confidence)")

# Render plot
plt.show()

# Run OLS regression
common.run_covid19_regression(_df, y_name, log_level=True)
# Out:
# Estimated COVID-19 effect: -71291412 ± 5377500 (95% confidence)
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     log_inbtou_spending   R-squared:                       0.987
# Model:                             OLS   Adj. R-squared:                  0.982
# Method:                  Least Squares   F-statistic:                     205.4
# Date:                 Wed, 26 Apr 2023   Prob (F-statistic):           6.61e-08
# Time:                         15:49:38   Log-Likelihood:                 22.035
# No. Observations:                   12   AIC:                            -36.07
# Df Residuals:                        8   BIC:                            -34.13
# Df Model:                            3
# Covariance Type:             nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                -31.1437     10.478     -2.972      0.018     -55.305      -6.982
# yr                         0.0246      0.005      4.727      0.001       0.013       0.037
# covid19_cases             -0.0077      0.000    -16.216      0.000      -0.009      -0.007
# covid19_cases:ind_2021     0.0075      0.000     15.914      0.000       0.006       0.009
# ==============================================================================
# Omnibus:                        2.669   Durbin-Watson:                   1.797
# Prob(Omnibus):                  0.263   Jarque-Bera (JB):                0.555
# Skew:                           0.353   Prob(JB):                        0.758
# Kurtosis:                       3.782   Cond. No.                     1.93e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     log_inbtou_spending   R-squared:                       0.566
# Model:                             OLS   Adj. R-squared:                  0.469
# Method:                  Least Squares   F-statistic:                     5.865
# Date:                 Wed, 26 Apr 2023   Prob (F-statistic):             0.0234
# Time:                         15:49:38   Log-Likelihood:                0.90033
# No. Observations:                   12   AIC:                             4.199
# Df Residuals:                        9   BIC:                             5.654
# Df Model:                            2
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  53.7446     49.800      1.079      0.309     -58.910     166.400
# yr                         -0.0176      0.025     -0.711      0.495      -0.073       0.038
# covid19_deaths             -0.0049      0.002     -2.597      0.029      -0.009      -0.001
# covid19_deaths:ind_2021    -0.0049      0.002     -2.597      0.029      -0.009      -0.001
# ==============================================================================
# Omnibus:                       13.547   Durbin-Watson:                   2.309
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                8.390
# Skew:                          -1.508   Prob(JB):                       0.0151
# Kurtosis:                       5.772   Cond. No.                     2.01e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     log_inbtou_spending   R-squared:                       0.566
# Model:                             OLS   Adj. R-squared:                  0.469
# Method:                  Least Squares   F-statistic:                     5.865
# Date:                 Wed, 26 Apr 2023   Prob (F-statistic):             0.0234
# Time:                         15:49:38   Log-Likelihood:                0.90033
# No. Observations:                   12   AIC:                             4.199
# Df Residuals:                        9   BIC:                             5.654
# Df Model:                            2
# Covariance Type:             nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     53.7446     49.800      1.079      0.309     -58.910     166.400
# yr                            -0.0176      0.025     -0.711      0.495      -0.073       0.038
# covid19_mortality            -28.3461     10.916     -2.597      0.029     -53.041      -3.652
# covid19_mortality:ind_2021   -28.3461     10.916     -2.597      0.029     -53.041      -3.652
# ==============================================================================
# Omnibus:                       13.547   Durbin-Watson:                   2.309
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                8.390
# Skew:                          -1.508   Prob(JB):                       0.0151
# Kurtosis:                       5.772   Cond. No.                     4.69e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.22e-36. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
