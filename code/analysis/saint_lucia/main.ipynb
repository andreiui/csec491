# %%
# Import libraries and load dataset
import os
import sys
import importlib
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm

import common.common as common
importlib.reload(common)

df = pd.read_csv("Data.csv")

yr = list(df.yr)
df = df.set_index("yr")
df["yr"] = yr
df
# Out:
#       inbtou_volume  inbtou_spending  covid19_cases  covid19_deaths
# yr
# 2010      1026340.0      564912300.0              0               0  \
# 2011       994960.0      585236400.0              0               0
# 2012       931220.0      592788100.0              0               0
# 2013       960620.0      654234000.0              0               0
# 2014      1034070.0      730794400.0              0               0
# 2015      1088180.0      767409600.0              0               0
# 2016      1004040.0      733180900.0              0               0
# 2017      1114760.0      836577400.0              0               0
# 2018      1228720.0      899643900.0              0               0
# 2019      1286000.0      997575500.0              0               0
# 2020       455410.0      317556200.0            353               5
# 2021       301680.0      775623600.0          13217             290
# 2022            NaN              NaN          16171             114
#
#       covid19_mortality    yr
# yr
# 2010           0.000000  2010
# 2011           0.000000  2011
# 2012           0.000000  2012
# 2013           0.000000  2013
# 2014           0.000000  2014
# 2015           0.000000  2015
# 2016           0.000000  2016
# 2017           0.000000  2017
# 2018           0.000000  2018
# 2019           0.000000  2019
# 2020           0.014164  2020
# 2021           0.021941  2021
# 2022           0.007050  2022

# %%
# Set up plot
plt.title('St Lucia')
plt.ylabel('Number of tourists')
plt.xlim(2009, 2022)
y_name = 'inbtou_volume'

# Filter out NaN data
_df = pd.DataFrame(df).loc[df[y_name].notna()]

# Generate difference-in-differences plot
effect, stderr = common.gen_did_plot(_df, y_name)
print(f"Estimated COVID-19 effect: {int(effect)} ± {int(stderr)} (95% confidence)")

# Render plot
plt.show()

# Run OLS regression
common.run_covid19_regression(_df, y_name, log_level=True)
# Out:
# Estimated COVID-19 effect: -866235 ± 81158 (95% confidence)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_inbtou_volume   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     158.3
# Date:                Wed, 26 Apr 2023   Prob (F-statistic):           1.84e-07
# Time:                        15:46:04   Log-Likelihood:                 18.241
# No. Observations:                  12   AIC:                            -28.48
# Df Residuals:                       8   BIC:                            -26.54
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                -42.1662     14.374     -2.934      0.019     -75.312      -9.020
# yr                         0.0278      0.007      3.899      0.005       0.011       0.044
# covid19_cases             -0.0028      0.000    -12.733      0.000      -0.003      -0.002
# covid19_cases:ind_2021     0.0027      0.000     12.359      0.000       0.002       0.003
# ==============================================================================
# Omnibus:                        0.070   Durbin-Watson:                   1.255
# Prob(Omnibus):                  0.966   Jarque-Bera (JB):                0.290
# Skew:                          -0.087   Prob(JB):                        0.865
# Kurtosis:                       2.259   Cond. No.                     4.17e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.17e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_inbtou_volume   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     158.3
# Date:                Wed, 26 Apr 2023   Prob (F-statistic):           1.84e-07
# Time:                        15:46:04   Log-Likelihood:                 18.241
# No. Observations:                  12   AIC:                            -28.48
# Df Residuals:                       8   BIC:                            -26.54
# Df Model:                           3
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                 -42.1662     14.374     -2.934      0.019     -75.312      -9.020
# yr                          0.0278      0.007      3.899      0.005       0.011       0.044
# covid19_deaths             -0.1999      0.016    -12.733      0.000      -0.236      -0.164
# covid19_deaths:ind_2021     0.1949      0.016     12.493      0.000       0.159       0.231
# ==============================================================================
# Omnibus:                        0.070   Durbin-Watson:                   1.255
# Prob(Omnibus):                  0.966   Jarque-Bera (JB):                0.290
# Skew:                          -0.087   Prob(JB):                        0.865
# Kurtosis:                       2.259   Cond. No.                     1.55e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.55e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_inbtou_volume   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     158.3
# Date:                Wed, 26 Apr 2023   Prob (F-statistic):           1.84e-07
# Time:                        15:46:04   Log-Likelihood:                 18.241
# No. Observations:                  12   AIC:                            -28.48
# Df Residuals:                       8   BIC:                            -26.54
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                    -42.1662     14.374     -2.934      0.019     -75.312      -9.020
# yr                             0.0278      0.007      3.899      0.005       0.011       0.044
# covid19_mortality            -70.5528      5.541    -12.733      0.000     -83.331     -57.775
# covid19_mortality:ind_2021     4.9700      5.509      0.902      0.393      -7.735      17.675
# ==============================================================================
# Omnibus:                        0.070   Durbin-Watson:                   1.255
# Prob(Omnibus):                  0.966   Jarque-Bera (JB):                0.290
# Skew:                          -0.087   Prob(JB):                        0.865
# Kurtosis:                       2.259   Cond. No.                     1.58e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
# Set up plot
plt.title('St Lucia')
plt.ylabel('Tourist expenditure (USD)')
plt.xlim(2009, 2022)
y_name = 'inbtou_spending'

# Filter out NaN data
_df = pd.DataFrame(df).loc[df[y_name].notna()]

# Generate difference-in-differences plot
effect, stderr = common.gen_did_plot(_df, y_name)
print(f"Estimated COVID-19 effect: {int(effect)} ± {int(stderr)} (95% confidence)")

# Render plot
plt.show()

# Run OLS regression
common.run_covid19_regression(_df, y_name, log_level=True)
# Out:
# Estimated COVID-19 effect: -480439004 ± 104726137 (95% confidence)
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     log_inbtou_spending   R-squared:                       0.986
# Model:                             OLS   Adj. R-squared:                  0.980
# Method:                  Least Squares   F-statistic:                     185.3
# Date:                 Wed, 26 Apr 2023   Prob (F-statistic):           9.90e-08
# Time:                         15:47:25   Log-Likelihood:                 23.612
# No. Observations:                   12   AIC:                            -39.22
# Df Residuals:                        8   BIC:                            -37.28
# Df Model:                            3
# Covariance Type:             nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               -104.6315      9.188    -11.388      0.000    -125.819     -83.444
# yr                         0.0621      0.005     13.608      0.000       0.052       0.073
# covid19_cases             -0.0033      0.000    -23.232      0.000      -0.004      -0.003
# covid19_cases:ind_2021     0.0033      0.000     23.272      0.000       0.003       0.004
# ==============================================================================
# Omnibus:                        4.124   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.127   Jarque-Bera (JB):                1.771
# Skew:                          -0.921   Prob(JB):                        0.413
# Kurtosis:                       3.382   Cond. No.                     4.17e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.17e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     log_inbtou_spending   R-squared:                       0.986
# Model:                             OLS   Adj. R-squared:                  0.980
# Method:                  Least Squares   F-statistic:                     185.3
# Date:                 Wed, 26 Apr 2023   Prob (F-statistic):           9.90e-08
# Time:                         15:47:25   Log-Likelihood:                 23.612
# No. Observations:                   12   AIC:                            -39.22
# Df Residuals:                        8   BIC:                            -37.28
# Df Model:                            3
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                -104.6315      9.188    -11.388      0.000    -125.819     -83.444
# yr                          0.0621      0.005     13.608      0.000       0.052       0.073
# covid19_deaths             -0.2331      0.010    -23.232      0.000      -0.256      -0.210
# covid19_deaths:ind_2021     0.2320      0.010     23.259      0.000       0.209       0.255
# ==============================================================================
# Omnibus:                        4.124   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.127   Jarque-Bera (JB):                1.771
# Skew:                          -0.921   Prob(JB):                        0.413
# Kurtosis:                       3.382   Cond. No.                     1.55e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.55e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     log_inbtou_spending   R-squared:                       0.986
# Model:                             OLS   Adj. R-squared:                  0.980
# Method:                  Least Squares   F-statistic:                     185.3
# Date:                 Wed, 26 Apr 2023   Prob (F-statistic):           9.90e-08
# Time:                         15:47:25   Log-Likelihood:                 23.612
# No. Observations:                   12   AIC:                            -39.22
# Df Residuals:                        8   BIC:                            -37.28
# Df Model:                            3
# Covariance Type:             nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   -104.6315      9.188    -11.388      0.000    -125.819     -83.444
# yr                             0.0621      0.005     13.608      0.000       0.052       0.073
# covid19_mortality            -82.2861      3.542    -23.232      0.000     -90.454     -74.118
# covid19_mortality:ind_2021    67.0374      3.522     19.036      0.000      58.916      75.158
# ==============================================================================
# Omnibus:                        4.124   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.127   Jarque-Bera (JB):                1.771
# Skew:                          -0.921   Prob(JB):                        0.413
# Kurtosis:                       3.382   Cond. No.                     1.58e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
